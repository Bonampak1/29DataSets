# %% [markdown]
# # Project Proposal
#
# ## Team Name: 29DataSets
#
# ### Jenine Rogel (UID and email)
# ### Ro Rague u1343169 u1343169@utah.edu

# %% [markdown]
# ### Repository: https://github.com/Bonampak1/29DataSets

# %% [markdown]
# # Trends of crime data over the years across Utah cities

# %% [markdown]
# ## Background and Motivation
# The idea for this project came after some thought about using a combination of the datasets with an Opioid dataset to evaluate if there were any specific trends involved with Opioid use and crime. We would use the location and years and see if there was an overlap.
# The current project idea is to see if there are general trends of crime data within specific cities and specific years and build visualizations on that data. We were both intersted in this topic because we were both from Utah but did not know much about the crime in UT.

# %% [markdown]
# ## Data
# We will be using data from https://opendata.utah.gov/, because there were multiple dataset CSVs we have to use, they were all downloaded and uploaded into our repository from above. The data is in the form of 29 CSV files.

# %% [markdown]
# ## Data Processing
# We do anticipate some data clean up with these files. For example, not all the files have the same columns, in the case of 'Cache_County_Sheriff_Police_Crime_Data' and 'Brigham_City_Police_Crime_Data', the 'Cache_County' CSV file contains an extra column 'country'. On that note, some of the CSV files are per county and others are per city. If we plan to do trends across different counties, we would have to merge the data accordingly on city per county. There are also some 'NAs' on Zip Codes that will have to be accounted for and we will have to align the years across all 29 datasets so that we have coverage of data across those years.
#
# Common columns:
# - Incident_id (except SLC)
# - Case_number(except SLC)
# - incident_datetime (except SLC)
# - incident_type_primary (except SLC)
# - incident_description (except SLC)
# - clearance_type (except SLC)
# - address_1 (except SLC)
# - city (except SLC)
# - state (except SLC)
# - Zip (except SLC & Syracuse)
# - Latitude (except SLC)
# - Longitude (except SLC)
# - created_at (except SLC)
# - updated_at (except SLC)
# - location (except SLC)
# - hour_of_day (except SLC)
# - day_of_week (except SLC)
# - parent_incident_type (except SLC)

# %% [markdown]
# ## Analysis Questions
# Primary questions:
# 1) Are there crime trends in different cities?
# 2) Are there crime trends with different years?
# 3) What different types of crime occurs, and which one is most prelavent per city?
#
# We would like to learn how to display and visualize this data in an unbiased and straightforward fashion. In the long-run, if a visualization worked it could be used to determine which areas in Utah to live. However, this could arise another issue with how a visualization can be harmful than helpful.

# %% [markdown]
# ## Visualization Design
# 1) A stream graph to show flowing trends of the crime data
# 2) Line graph, this is an interesting reference: https://cde.ucr.cjis.gov/LATEST/webapp/#/pages/explorer/crime/crime-trend
#
# 3) Percentage change bar graph that would show any increases and decreases of crime and even certain crime in areas.
# EXAMPLE BELOW
# ![image.png](attachment:d4cf7e0e-a477-4e9e-add9-a56bcb97f0e5.png)

# %% [markdown]
# ## Must Have Features
# 1) Year
# 2) City or County, whichever we decide
# 3) Incident date time
# 4) Incident ID
# 5) Incident Type Primary
# 6) Address and Zip code (?)

# %% [markdown]
# ## Optional Features
# 1) The Opioid dataset to cross-compare Opioid usage and if there is any correlation with crime

# %% [markdown]
# ## Project Schedule
# 1) 10/20/2023 - finish rough draft of project proposal
# 2) 10/27/2023 -- finish final draft of project proposal
# 3) 11/03/2023 -- start initial EDA of data, begin data clean up
# 4) 11/10/2023 -- start look at trends, maybe run some statistics to determine how to build the visualization
# 5) 11/17/2023 -- build rough draft of first visualization
# 6) 11/24/2023 -- finish final visualization
